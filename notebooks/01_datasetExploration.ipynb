# %% [markdown]
# # DATA EXPLORATION & PREPROCESSING

# %% [markdown]
# ## Load and Inspect

# %% [markdown]
# **Dataset Information**:
#
# - **Name**: Furniture Sales Data
# - **Rows**: 2500 patterns
# - **Columns**: 15 columns (7 numerical, 7 categorical, 1 target variable (revenue))
# - It is synthetic (or semi-synthetic) for regression / multiple regression practice.

# %% [markdown]
# ## Missing Values

# %% [markdown]
# ## Encode Categorical Variables

# %% [markdown]
# ## Outlier Detection

# %% [markdown]
# ## Normalization / Transformation

# %% [markdown]
# ## Train/Test Split

# %% [markdown]
# ## Export Preprocessed Files
