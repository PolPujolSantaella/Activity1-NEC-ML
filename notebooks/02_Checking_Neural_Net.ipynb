# %%
import pandas as pd

df = pd.read_csv('../data/processed/SalesRevenue_processed.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   IsPromotionApplied             2000 non-null   int64
#  1   ProductionCost                 2000 non-null   float64
#  2   MarketingSpend                 2000 non-null   float64
#  3   SeasonalDemandIndex            2000 non-null   float64
#  4   CompetitorPrice                2000 non-null   float64
#  5   CustomerRating                 2000 non-null   float64
#  6   EconomicIndex                  2000 non-null   float64
#  7   StoreCount                     2000 non-null   float64
#  8   SalesRevenue                   2000 non-null   int64
#  9   ProductCategory_Electronics    2000 non-null   int64
#  10  ProductCategory_Furniture      2000 non-null   int64
#  11  ProductCategory_Toys           2000 non-null   int64
#  12  Region_North                   2000 non-null   int64
#  13  Region_South                   2000 non-null   int64
#  14  Region_West                    2000 non-null   int64
#  15  CustomerSegment_Low Income     2000 non-null   int64
#  16  CustomerSegment_Middle Income  2000 non-null   int64
# dtypes: float64(7), int64(10)
# memory usage: 265.8 KB

# %%
import sys
import os

# Añadir la carpeta src al path
sys.path.append(os.path.abspath("../src"))

from NeuralNet import NeuralNet

X = df.drop(columns=['SalesRevenue'])
y = df['SalesRevenue']

print(f"{X.info()}")

layers = [16, 32, 16, 1]
epochs = 240
learning_rate = 0.001
momentum = 0.9
fact = "linear"
validation_split = 0.2

nn = NeuralNet(layers, epochs, learning_rate, momentum, fact, validation_split)

# Entrenar el modelo
nn.fit(X, y)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   IsPromotionApplied             2000 non-null   int64
#  1   ProductionCost                 2000 non-null   float64
#  2   MarketingSpend                 2000 non-null   float64
#  3   SeasonalDemandIndex            2000 non-null   float64
#  4   CompetitorPrice                2000 non-null   float64
#  5   CustomerRating                 2000 non-null   float64
#  6   EconomicIndex                  2000 non-null   float64
#  7   StoreCount                     2000 non-null   float64
#  8   ProductCategory_Electronics    2000 non-null   int64
#  9   ProductCategory_Furniture      2000 non-null   int64
#  10  ProductCategory_Toys           2000 non-null   int64
#  11  Region_North                   2000 non-null   int64
#  12  Region_South                   2000 non-null   int64
#  13  Region_West                    2000 non-null   int64
#  14  CustomerSegment_Low Income     2000 non-null   int64
#  15  CustomerSegment_Middle Income  2000 non-null   int64
# dtypes: float64(7), int64(9)
# memory usage: 250.1 KB
# None
# [16, 32, 16, 1]
#
# Epoch 0: Feed-forward CHECK
# Input layer activation: [ 1.          1.13881609  1.66614944  0.02263589 -0.44274388  0.88175978
#  -0.55963129  0.63337028  0.          1.          0.          0.
#   1.          0.          0.          1.        ]
# Hidden Layer 1 activation: [-0.48701881  1.86266519  0.76115052  1.36027156  0.46838877  1.63539467
